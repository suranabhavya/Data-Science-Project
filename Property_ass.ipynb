# %%
import pandas as pd
import numpy as np

# %%
data_pa = pd.read_csv('/Users/muskanj/Documents/CS_TDS_506/fy2025-property_assessment.csv')
data_pa.head(n = 10)
# Out:
# /var/folders/rr/jgxtpr1s2dg4_53pkplmjvhc0000gn/T/ipykernel_6553/637951721.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_pa = pd.read_csv('/Users/muskanj/Documents/CS_TDS_506/fy2025-property_assessment.csv')
#          PID        CM_ID     GIS_ID  ST_NUM  ST_NUM2       ST_NAME UNIT_NUM  \
# 0  100001000          NaN  100001000   104.0      NaN     PUTNAM ST      NaN
# 1  100002000          NaN  100002000   197.0      NaN  Lexington ST      NaN
# 2  100003000          NaN  100003000   199.0      NaN  Lexington ST      NaN
# 3  100004000          NaN  100004000   201.0      NaN  Lexington ST      NaN
# 4  100005000          NaN  100005000   203.0      NaN  Lexington ST      NaN
# 5  100006000          NaN  100006000   205.0    207.0  Lexington ST      NaN
# 6  100007000          NaN  100007000   209.0    211.0  Lexington ST      NaN
# 7  100008000          NaN  100008000   213.0      NaN  Lexington ST      NaN
# ...

# %%
pd.set_option('display.max_columns', None)
print(data_pa.head())
# Out:
#          PID  CM_ID     GIS_ID  ST_NUM  ST_NUM2       ST_NAME UNIT_NUM  \
# 0  100001000    NaN  100001000   104.0      NaN     PUTNAM ST      NaN
# 1  100002000    NaN  100002000   197.0      NaN  Lexington ST      NaN
# 2  100003000    NaN  100003000   199.0      NaN  Lexington ST      NaN
# 3  100004000    NaN  100004000   201.0      NaN  Lexington ST      NaN
# 4  100005000    NaN  100005000   203.0      NaN  Lexington ST      NaN
#
#           CITY  ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC  LU             LU_DESC  \
# 0  EAST BOSTON    2128.0         1          1  105  R3  THREE-FAM DWELLING
# 1  EAST BOSTON    2128.0         1          1  105  R3  THREE-FAM DWELLING
# 2  EAST BOSTON    2128.0         1          1  105  R3  THREE-FAM DWELLING
# 3  EAST BOSTON    2128.0         1          1  105  R3  THREE-FAM DWELLING
# 4  EAST BOSTON    2128.0         1          1  104  R2    TWO-FAM DWELLING
#
#          BLDG_TYPE OWN_OCC                   OWNER MAIL_ADDRESSEE  \
# ...

# %%
data_pa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183445 entries, 0 to 183444
# Data columns (total 66 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   PID                  183445 non-null  int64
#  1   CM_ID                94723 non-null   float64
#  2   GIS_ID               183445 non-null  int64
#  3   ST_NUM               174130 non-null  float64
#  4   ST_NUM2              22165 non-null   float64
#  5   ST_NAME              183445 non-null  object
#  6   UNIT_NUM             83855 non-null   object
#  7   CITY                 183442 non-null  object
#  8   ZIP_CODE             183442 non-null  float64
#  9   BLDG_SEQ             183445 non-null  int64
#  10  NUM_BLDGS            183445 non-null  int64
#  11  LUC                  183445 non-null  int64
#  12  LU                   183445 non-null  object
#  13  LU_DESC              183445 non-null  object
#  14  BLDG_TYPE            180310 non-null  object
# ...

# %%
data_pa
# Out:
#                PID  CM_ID      GIS_ID  ST_NUM  ST_NUM2          ST_NAME  \
# 0        100001000    NaN   100001000   104.0      NaN        PUTNAM ST
# 1        100002000    NaN   100002000   197.0      NaN     Lexington ST
# 2        100003000    NaN   100003000   199.0      NaN     Lexington ST
# 3        100004000    NaN   100004000   201.0      NaN     Lexington ST
# 4        100005000    NaN   100005000   203.0      NaN     Lexington ST
# ...            ...    ...         ...     ...      ...              ...
# 183440  2205666000    NaN  2205666000     NaN      NaN       KNOWLES ST
# 183441  2205667000    NaN  2205667000     NaN      NaN          Lake ST
# 183442  2205668000    NaN  2205668000     4.0      NaN          Lake ST
# 183443  2205669000    NaN  2205669000  2193.0   2201.0  COMMONWEALTH AV
# 183444  2205670000    NaN  2205670000  2203.0      NaN  COMMONWEALTH AV
#
#        UNIT_NUM         CITY  ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC       LU  \
# ...

# %%
mostly_nan = data_pa.isnull().mean()
print(mostly_nan[mostly_nan > 0.5])
# Out:
# ST_NUM2            0.879174
# UNIT_NUM           0.542888
# MAIL_ADDRESSEE     0.810434
# CD_FLOOR           0.600005
# RES_UNITS          0.940265
# COM_UNITS          0.940265
# RC_UNITS           0.940265
# YR_REMODEL         0.520385
# STRUCTURE_CLASS    0.905225
# BDRM_COND          0.601123
# BTHRM_STYLE2       0.524789
# BTHRM_STYLE3       0.794805
# KITCHEN_STYLE2     0.827594
# KITCHEN_STYLE3     0.923508
# HEAT_SYSTEM        0.598495
# ORIENTATION        0.598730
# CORNER_UNIT        0.598664
# dtype: float64

# %%
# Removed the columns with NaN values greater than ~80%

cols_to_drop = [
    'ST_NUM2', 'MAIL_ADDRESSEE', 'RES_UNITS', 'COM_UNITS', 
    'RC_UNITS', 'STRUCTURE_CLASS', 'KITCHEN_STYLE2', 'KITCHEN_STYLE3', 'BTHRM_STYLE3',

     'CD_FLOOR' #not useful
]

data_pa = data_pa.drop(columns=cols_to_drop)

# %%
data_pa
# Out:
#                PID  CM_ID      GIS_ID  ST_NUM          ST_NAME UNIT_NUM  \
# 0        100001000    NaN   100001000   104.0        PUTNAM ST      NaN
# 1        100002000    NaN   100002000   197.0     Lexington ST      NaN
# 2        100003000    NaN   100003000   199.0     Lexington ST      NaN
# 3        100004000    NaN   100004000   201.0     Lexington ST      NaN
# 4        100005000    NaN   100005000   203.0     Lexington ST      NaN
# ...            ...    ...         ...     ...              ...      ...
# 183440  2205666000    NaN  2205666000     NaN       KNOWLES ST      NaN
# 183441  2205667000    NaN  2205667000     NaN          Lake ST      NaN
# 183442  2205668000    NaN  2205668000     4.0          Lake ST      NaN
# 183443  2205669000    NaN  2205669000  2193.0  COMMONWEALTH AV      NaN
# 183444  2205670000    NaN  2205670000  2203.0  COMMONWEALTH AV      NaN
#
#                CITY  ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC       LU  \
# ...

# %%
mostly_nan = data_pa.isnull().mean()
print(mostly_nan[mostly_nan > 0.2])
# Out:
# CM_ID             0.483644
# UNIT_NUM          0.542888
# YR_REMODEL        0.520385
# INT_WALL          0.264973
# INT_COND          0.264957
# BED_RMS           0.265044
# TT_RMS            0.265458
# BDRM_COND         0.601123
# BTHRM_STYLE1      0.264068
# BTHRM_STYLE2      0.524789
# KITCHEN_TYPE      0.264155
# KITCHEN_STYLE1    0.264101
# HEAT_TYPE         0.262209
# HEAT_SYSTEM       0.598495
# AC_TYPE           0.262373
# ORIENTATION       0.598730
# NUM_PARKING       0.264145
# PROP_VIEW         0.254458
# CORNER_UNIT       0.598664
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cat_cols = ['INT_WALL', 'INT_COND', 'KITCHEN_TYPE', 'BTHRM_STYLE1', 'BTHRM_STYLE2']
for col in cat_cols:
    plt.figure(figsize=(6, 3))
    sns.countplot(data=data_pa, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
num_cols = ['YR_REMODEL', 'NUM_PARKING']
for col in num_cols:
    plt.figure(figsize=(6, 3))
    sns.histplot(data_pa[col].dropna(), kde=True, bins=20)
    plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()

# %%
print("CM_ID unique count:", data_pa['CM_ID'].nunique())
print("CM_ID total count:", data_pa['CM_ID'].count())
# Out:
# CM_ID unique count: 10960
# CM_ID total count: 94723

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_ids = data_pa['CM_ID'].value_counts().head(10)
sns.barplot(x=top_ids.index.astype(str), y=top_ids.values)
plt.title("Top 10 CM_ID Frequencies")
plt.xticks(rotation=45)
plt.show()

# %%
cols = ['BDRM_COND', 'HEAT_SYSTEM', 'ORIENTATION', 'CORNER_UNIT']
for col in cols:
    plt.figure(figsize=(6,3))
    sns.countplot(data=data_pa, x=col, order=data_pa[col].value_counts().index)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
print(data_pa[cols].isnull().mean().sort_values(ascending=False))
# Out:
# BDRM_COND      0.601123
# ORIENTATION    0.598730
# CORNER_UNIT    0.598664
# HEAT_SYSTEM    0.598495
# dtype: float64

# %%
categorical_cols = [
    'BDRM_COND', 'HEAT_SYSTEM', 'ORIENTATION', 'CORNER_UNIT', 'ROOF_STRUCTURE',
    'INT_WALL', 'EXT_FNISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND',
    'BTHRM_STYLE1', 'BTHRM_STYLE2', 'KITCHEN_TYPE', 'KITCHEN_STYLE1',
    'HEAT_TYPE', 'AC_TYPE', 'PROP_VIEW'
]

for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(data_pa[col].value_counts(dropna=False))
# Out:
# --- BDRM_COND ---
# BDRM_COND
# NaN              110273
# A - Average       58247
# G - Good          13070
# E - Excellent       961
# F - Fair            832
# P - Poor             62
# Name: count, dtype: int64
#
# --- HEAT_SYSTEM ---
# HEAT_SYSTEM
# NaN                   109791
# I - Indiv. Cntrl       45341
# Y - Self Contained     19247
# C - Common              8041
# N - None                 967
# 1                         58
# Name: count, dtype: int64
#
# --- ORIENTATION ---
# ORIENTATION
# NaN                 109834
# T - Through          38293
# F - Front/Street     18498
# A - Rear Above       10706
# M - Middle            2740
# C - Courtyard         1788
# B - Rear Below        1293
# E - End                293
# Name: count, dtype: int64
#
# --- CORNER_UNIT ---
# CORNER_UNIT
# NaN        109822
# N - No      59363
# Y - Yes     14260
# Name: count, dtype: int64
#
# --- ROOF_STRUCTURE ---
# ROOF_STRUCTURE
# F - Flat       69986
# G - Gable      46758
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Columns of interest
categorical_cols = [
    'BDRM_COND', 'HEAT_SYSTEM', 'ORIENTATION', 'CORNER_UNIT', 'ROOF_STRUCTURE',
    'INT_WALL', 'EXT_FNISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND',
    'BTHRM_STYLE1', 'BTHRM_STYLE2', 'KITCHEN_TYPE', 'KITCHEN_STYLE1',
    'HEAT_TYPE', 'AC_TYPE', 'PROP_VIEW'
]

# Limit rare values and get top 5 categories for each column
top_n = 5
heatmap_data = pd.DataFrame()

for col in categorical_cols:
    top_categories = data_pa[col].value_counts(normalize=True, dropna=False).head(top_n)
    temp_df = pd.DataFrame(top_categories).T
    temp_df.index = [col]
    heatmap_data = pd.concat([heatmap_data, temp_df], axis=0)

# Fill NaNs with 0 (for categories not in top_n)
heatmap_data = heatmap_data.fillna(0)

# Plot
plt.figure(figsize=(16, 10))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="Blues", cbar_kws={'label': 'Proportion'})
plt.title("Top Category Proportions Across Categorical Columns")
plt.ylabel("Column")
plt.xlabel("Category")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
cardinality = data_pa[categorical_cols].nunique(dropna=False).sort_values()

plt.figure(figsize=(10,6))
sns.barplot(x=cardinality.values, y=cardinality.index)
plt.title("Number of Unique Categories per Categorical Column")
plt.xlabel("Unique Values")
plt.ylabel("Column")
plt.tight_layout()
plt.show()

# %%
from scipy.stats import entropy

entropy_scores = {}
for col in categorical_cols:
    counts = data_pa[col].value_counts(normalize=True, dropna=False)
    entropy_scores[col] = entropy(counts)

entropy_df = pd.Series(entropy_scores).sort_values()

plt.figure(figsize=(10,6))
sns.barplot(x=entropy_df.values, y=entropy_df.index)
plt.title("Entropy (Category Diversity) of Categorical Columns")
plt.xlabel("Entropy")
plt.ylabel("Column")
plt.tight_layout()
plt.show()

# %%
same_style = (data_pa['BTHRM_STYLE1'] == data_pa['BTHRM_STYLE2']).sum()
print("Same style in both cols:", same_style)
# Out:
# Same style in both cols: 75204

# %%
combo_counts = data_pa[['BTHRM_STYLE1', 'BTHRM_STYLE2']].value_counts(dropna=False).sort_values(ascending=False)
print("Top combinations:\n", combo_counts)
# Out:
# Top combinations:
#  BTHRM_STYLE1       BTHRM_STYLE2
# NaN                NaN                  48441
# M - Modern         M - Modern           37203
# S - Semi-Modern    S - Semi-Modern      31031
#                    NaN                  23450
# M - Modern         NaN                  21251
#                    S - Semi-Modern       4305
# L - Luxury         L - Luxury            4127
# N - No Remodeling  N - No Remodeling     2843
# S - Semi-Modern    M - Modern            2745
# L - Luxury         M - Modern            2663
# N - No Remodeling  NaN                   1930
# L - Luxury         NaN                   1198
# S - Semi-Modern    N - No Remodeling      866
# N - No Remodeling  S - Semi-Modern        783
# M - Modern         N - No Remodeling      288
# N - No Remodeling  M - Modern             185
# M - Modern         L - Luxury              91
# L - Luxury         S - Semi-Modern         29
# S - Semi-Modern    L - Luxury              12
# ...

# %%
pd.crosstab(data_pa['BTHRM_STYLE1'], data_pa['BTHRM_STYLE2'], dropna=False)
# Out:
# BTHRM_STYLE2       L - Luxury  M - Modern  N - No Remodeling  S - Semi-Modern  \
# BTHRM_STYLE1
# L - Luxury               4127        2663                  3               29
# M - Modern                 91       37203                288             4305
# N - No Remodeling           0         185               2843              783
# S - Semi-Modern            12        2745                866            31031
# NaN                         0           0                  1                0
#
# BTHRM_STYLE2         NaN
# BTHRM_STYLE1
# L - Luxury          1198
# M - Modern         21251
# N - No Remodeling   1930
# S - Semi-Modern    23450
# NaN                48441

# %%
# Only ~10% of rows have different STYLE1 and STYLE2
# BTHRM_STYLE2 rarely adds new dominant info and STYLE2 Is Frequently Missing

data_pa = data_pa.drop(columns=['BTHRM_STYLE2'])

# %%
import pandas as pd

categorical_cols = [
    'BDRM_COND', 'HEAT_SYSTEM', 'ORIENTATION', 'CORNER_UNIT', 'ROOF_STRUCTURE',
    'INT_WALL', 'EXT_FNISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND',
    'BTHRM_STYLE1', 'KITCHEN_TYPE', 'KITCHEN_STYLE1',
    'HEAT_TYPE', 'AC_TYPE', 'PROP_VIEW'
]

# Apply transformation to each categorical column
for col in categorical_cols:
    data_pa[col] = data_pa[col].fillna("NA")                      # Replace NaN with 'NA'
    data_pa[col] = data_pa[col].astype(str).str.split(" - ").str[0]  # Keep only the code before ' - '

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reuse the cleaned list
categorical_cols = [
    'BDRM_COND', 'HEAT_SYSTEM', 'ORIENTATION', 'CORNER_UNIT', 'ROOF_STRUCTURE',
    'INT_WALL', 'EXT_FNISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND',
    'BTHRM_STYLE1', 'KITCHEN_TYPE', 'KITCHEN_STYLE1',
    'HEAT_TYPE', 'AC_TYPE', 'PROP_VIEW', 'ROOF_COVER'
]

# Build heatmap-friendly DataFrame
top_n = 5  # show only top 5 categories per column
heatmap_data = pd.DataFrame()

for col in categorical_cols:
    top_values = data_pa[col].value_counts(normalize=True).head(top_n)
    temp_df = pd.DataFrame(top_values).T
    temp_df.index = [col]
    heatmap_data = pd.concat([heatmap_data, temp_df], axis=0)

heatmap_data = heatmap_data.fillna(0)

# Plot heatmap
plt.figure(figsize=(16, 10))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={'label': 'Proportion'})
plt.title("Top Category Proportions Across Cleaned Categorical Columns")
plt.xlabel("Category")
plt.ylabel("Column")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data_pa[['BED_RMS', 'FULL_BTH', 'TT_RMS']].describe()
# Out:
#              BED_RMS       FULL_BTH         TT_RMS
# count  134824.000000  171043.000000  134748.000000
# mean        3.140791       1.375642       6.917030
# std         2.104657       1.065191       4.002484
# min         0.000000       0.000000       1.000000
# 25%         2.000000       1.000000       4.000000
# 50%         3.000000       1.000000       6.000000
# 75%         4.000000       2.000000       9.000000
# max        21.000000      21.000000      20.000000

# %%
categorical_cols = [
    'BDRM_COND', 'HEAT_SYSTEM', 'ORIENTATION', 'CORNER_UNIT', 'ROOF_STRUCTURE',
    'INT_WALL', 'EXT_FNISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND',
    'BTHRM_STYLE1', 'KITCHEN_TYPE', 'KITCHEN_STYLE1',
    'HEAT_TYPE', 'AC_TYPE', 'PROP_VIEW'
]

for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(data_pa[col].value_counts(dropna=False))
# Out:
# --- BDRM_COND ---
# BDRM_COND
# NA    110273
# A      58247
# G      13070
# E        961
# F        832
# P         62
# Name: count, dtype: int64
#
# --- HEAT_SYSTEM ---
# HEAT_SYSTEM
# NA    109791
# I      45341
# Y      19247
# C       8041
# N        967
# 1         58
# Name: count, dtype: int64
#
# --- ORIENTATION ---
# ORIENTATION
# NA    109834
# T      38293
# F      18498
# A      10706
# M       2740
# C       1788
# B       1293
# E        293
# Name: count, dtype: int64
#
# --- CORNER_UNIT ---
# CORNER_UNIT
# NA    109822
# N      59363
# Y      14260
# Name: count, dtype: int64
#
# --- ROOF_STRUCTURE ---
# ROOF_STRUCTURE
# F     69986
# G     46758
# NA    36067
# H     14035
# M     13729
# L      2153
# S       372
# O       345
# Name: count, dtype: int64
#
# --- INT_WALL ---
# INT_WALL
# N     129555
# NA     48608
# E       5195
# S         84
# G          3
# Name: count, dtype: int64
#
# --- EXT_FNISHED ---
# EXT_FNISHED
# B     52716
# M     42786
# ...

# %%
data_pa
# Out:
#                PID  CM_ID      GIS_ID  ST_NUM          ST_NAME UNIT_NUM  \
# 0        100001000    NaN   100001000   104.0        PUTNAM ST      NaN
# 1        100002000    NaN   100002000   197.0     Lexington ST      NaN
# 2        100003000    NaN   100003000   199.0     Lexington ST      NaN
# 3        100004000    NaN   100004000   201.0     Lexington ST      NaN
# 4        100005000    NaN   100005000   203.0     Lexington ST      NaN
# ...            ...    ...         ...     ...              ...      ...
# 183440  2205666000    NaN  2205666000     NaN       KNOWLES ST      NaN
# 183441  2205667000    NaN  2205667000     NaN          Lake ST      NaN
# 183442  2205668000    NaN  2205668000     4.0          Lake ST      NaN
# 183443  2205669000    NaN  2205669000  2193.0  COMMONWEALTH AV      NaN
# 183444  2205670000    NaN  2205670000  2203.0  COMMONWEALTH AV      NaN
#
#                CITY  ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC       LU  \
# ...

# %%
print("--- ROOF_COVER ---")
print(data_pa['ROOF_COVER'].value_counts(dropna=False))

print("\n--- BLDG_TYPE ---")
print(data_pa['BLDG_TYPE'].value_counts(dropna=False))
# Out:
# --- ROOF_COVER ---
# ROOF_COVER
# A - Asphalt Shingl    64115
# R - Rubber Roof       47784
# NaN                   36059
# C - Composition       22517
# S - Slate             11791
# O - Other               798
# T - Tile                267
# W - Wood Shingle        114
# Name: count, dtype: int64
#
# --- BLDG_TYPE ---
# BLDG_TYPE
# RM - Row Middle                 17765
# CL - Colonial                   16784
# LR - Low Rise                   15802
# MR - Mid Rise                   15466
# DK - Decker                     14621
#                                 ...
# 366 - FIELDHOUSE/TRACK              1
# 382 - STABLE(S)                     1
# 417 - DAIRY                         1
# 943 - COMPUTER /SCIENCE LAB         1
# 436 - STUDIO /Remote Control        1
# Name: count, Length: 203, dtype: int64

# %%
data_pa['ROOF_COVER'] = data_pa['ROOF_COVER'].fillna('NA')
data_pa['ROOF_COVER'] = data_pa['ROOF_COVER'].astype(str).str.split(' - ').str[0]

# %%
data_pa.columns = data_pa.columns.str.strip()

# %%
# Show unique raw values in GROSS_TAX
# See value frequencies (sorted)
print(data_pa['GROSS_TAX'].value_counts(dropna=False).sort_index())
# Out:
# GROSS_TAX
# $-                18807
# $1,000,539.39         1
# $1,000.51             6
# $1,001.67             3
# $1,002.83             2
#                   ...
# $998,273.24           1
# $998.20               1
# $999,480.77           1
# $999.35               7
# $999.46               3
# Name: count, Length: 40488, dtype: int64

# %%
import numpy as np

data_pa['GROSS_TAX'] = (
    data_pa['GROSS_TAX']
    .astype(str)
    .str.strip()  # remove leading/trailing whitespace
    .str.replace(r'\s+', '', regex=True)  # remove all internal whitespace
    .str.replace(r'[\$,]', '', regex=True)  # remove dollar signs and commas
    .str.replace(r'^-$', '0', regex=True)  # standalone '-' becomes 0
    .str.replace(r'^-$|^-?\$?$', '0', regex=True)  # edge case: "$-", "-$", "-"
    .replace('', '0')  # empty strings to 0
    .astype(float)
)

# %%
print(data_pa['GROSS_TAX'].value_counts(dropna=False).sort_index())
# Out:
# GROSS_TAX
# 0.00           18807
# 1.16               1
# 2.32               5
# 3.47               3
# 4.63               7
#                ...
# 16132719.99        1
# 16320197.92        1
# 17080550.74        1
# 22339737.82        1
# 23298240.72        1
# Name: count, Length: 40488, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data_pa['GROSS_TAX'], bins=50, kde=True)
plt.title('Distribution of GROSS_TAX')
plt.xlabel('Gross Tax ($)')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Avoid log(0): add a small constant or filter 0s
data_pa['LOG_GROSS_TAX'] = np.log1p(data_pa['GROSS_TAX'])  # log(1 + x)

# Plot transformed distribution
sns.histplot(data_pa['LOG_GROSS_TAX'], bins=50, kde=True)
plt.title('Log-Transformed Distribution of GROSS_TAX')
plt.xlabel('log(1 + Gross Tax)')
plt.ylabel('Frequency')
plt.show()

# %%
data_pa['GROSS_TAX_LOG'] = np.log1p(data_pa['GROSS_TAX'])

# %%
data_pa
# Out:
#                PID  CM_ID      GIS_ID  ST_NUM          ST_NAME UNIT_NUM  \
# 0        100001000    NaN   100001000   104.0        PUTNAM ST      NaN
# 1        100002000    NaN   100002000   197.0     Lexington ST      NaN
# 2        100003000    NaN   100003000   199.0     Lexington ST      NaN
# 3        100004000    NaN   100004000   201.0     Lexington ST      NaN
# 4        100005000    NaN   100005000   203.0     Lexington ST      NaN
# ...            ...    ...         ...     ...              ...      ...
# 183440  2205666000    NaN  2205666000     NaN       KNOWLES ST      NaN
# 183441  2205667000    NaN  2205667000     NaN          Lake ST      NaN
# 183442  2205668000    NaN  2205668000     4.0          Lake ST      NaN
# 183443  2205669000    NaN  2205669000  2193.0  COMMONWEALTH AV      NaN
# 183444  2205670000    NaN  2205670000  2203.0  COMMONWEALTH AV      NaN
#
#                CITY  ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC       LU  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Strip commas only for plotting (non-destructive)
temp_land_sf = data_pa['LAND_SF'].replace(',', '', regex=True).astype(float)

plt.figure(figsize=(8, 4))
sns.histplot(temp_land_sf, bins=50, kde=True)
plt.title('Distribution of LAND_SF')
plt.xlabel('Land Square Feet')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
data_pa['LAND_SF'].unique()
# Out:
# array(['1,150', '2,010', '2,500', ..., '10,838', '7,823', '34,125'],
#       dtype=object)

# %%
#Converting comma separated nums to float

for col in ['LAND_SF']:
    data_pa[col] = data_pa[col].replace(',', '', regex=True).astype(float)

# %%
data_pa['LAND_SF'].unique()
# Out:
# array([ 1150.,  2010.,  2500., ..., 10838.,  7823., 34125.])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

to_float = [
    'GROSS_AREA', 'LIVING_AREA', 'LAND_VALUE',
    'BLDG_VALUE', 'SFYI_VALUE', 'TOTAL_VALUE',
    'YR_BUILT', 'YR_REMODEL'
]

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(16, 16))
axes = axes.flatten()

for i, col in enumerate(to_float):
    sns.histplot(data_pa[col], bins=50, kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
for col in ['LAND_VALUE', 'BLDG_VALUE', 'TOTAL_VALUE', 'SFYI_VALUE']:
    data_pa[col] = data_pa[col].replace(',', '', regex=True).astype(float)

# %%
data_pa = data_pa.drop(columns=['GROSS_TAX_LOG'], errors='ignore')

# %%
for col in to_float:
    data_pa[col] = data_pa[col].clip(upper=data_pa[col].quantile(0.99))

# %%
import numpy as np

log_cols = ['GROSS_AREA', 'LIVING_AREA', 'LAND_VALUE', 'BLDG_VALUE', 'TOTAL_VALUE', 'SFYI_VALUE']

for col in log_cols:
    data_pa[f'LOG_{col}'] = np.log1p(data_pa[col])  # log1p handles 0s safely

# %%
import matplotlib.pyplot as plt
import seaborn as sns

log_cols = ['LOG_LAND_VALUE', 'LOG_BLDG_VALUE', 'LOG_TOTAL_VALUE', 'LOG_SFYI_VALUE', 'LOG_GROSS_AREA', 'LOG_LIVING_AREA']

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 12))
axes = axes.flatten()

for i, col in enumerate(log_cols):
    sns.histplot(data_pa[col].dropna(), bins=50, kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
print("YR_BUILT unique values (sample):", sorted(data_pa['YR_BUILT'].dropna().unique())[:20])
# Out:
# YR_BUILT unique values (sample): [1700.0, 1710.0, 1725.0, 1752.0, 1760.0, 1775.0, 1779.0, 1780.0, 1785.0, 1789.0, 1790.0, 1791.0, 1792.0, 1798.0, 1799.0, 1800.0, 1802.0, 1803.0, 1804.0, 1805.0]

# %%
print("YR_BUILT unique values:", sorted(data_pa['YR_BUILT'].dropna().unique()))
# Out:
# YR_BUILT unique values: [1700.0, 1710.0, 1725.0, 1752.0, 1760.0, 1775.0, 1779.0, 1780.0, 1785.0, 1789.0, 1790.0, 1791.0, 1792.0, 1798.0, 1799.0, 1800.0, 1802.0, 1803.0, 1804.0, 1805.0, 1806.0, 1807.0, 1808.0, 1809.0, 1810.0, 1811.0, 1812.0, 1814.0, 1816.0, 1818.0, 1819.0, 1820.0, 1821.0, 1822.0, 1823.0, 1824.0, 1825.0, 1826.0, 1827.0, 1828.0, 1829.0, 1830.0, 1831.0, 1832.0, 1833.0, 1834.0, 1835.0, 1836.0, 1837.0, 1838.0, 1839.0, 1840.0, 1841.0, 1842.0, 1843.0, 1844.0, 1845.0, 1846.0, 1847.0, 1848.0, 1849.0, 1850.0, 1851.0, 1852.0, 1853.0, 1854.0, 1855.0, 1856.0, 1857.0, 1858.0, 1859.0, 1860.0, 1861.0, 1862.0, 1863.0, 1864.0, 1865.0, 1866.0, 1867.0, 1868.0, 1869.0, 1870.0, 1871.0, 1872.0, 1873.0, 1874.0, 1875.0, 1876.0, 1877.0, 1878.0, 1879.0, 1880.0, 1881.0, 1882.0, 1883.0, 1884.0, 1885.0, 1886.0, 1887.0, 1888.0, 1889.0, 1890.0, 1891.0, 1892.0, 1893.0, 1894.0, 1895.0, 1896.0, 1897.0, 1898.0, 1899.0, 1900.0, 1901.0, 1902.0, 1903.0, 1904.0, 1905.0, 1906.0, 1907.0, 1908.0, 1909.0, 1910.
# ...

# %%
print("YR_REMODEL unique values:", sorted(data_pa['YR_REMODEL'].dropna().unique()))
# Out:
# YR_REMODEL unique values: [0.0, 201.0, 221.0, 1900.0, 1902.0, 1904.0, 1910.0, 1914.0, 1916.0, 1919.0, 1920.0, 1923.0, 1925.0, 1927.0, 1928.0, 1930.0, 1933.0, 1934.0, 1935.0, 1937.0, 1939.0, 1940.0, 1941.0, 1942.0, 1945.0, 1947.0, 1948.0, 1949.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0, 2023.0]

# %%
bad_remodel_mask = (data_pa['YR_REMODEL'] < 1700) | (data_pa['YR_REMODEL'] > 2025)
bad_remodel_count = bad_remodel_mask.sum()
print("Number of rows with bad YR_REMODEL values:", bad_remodel_count)
# Out:
# Number of rows with bad YR_REMODEL values: 5

# %%
data_pa = data_pa[~((data_pa['YR_REMODEL'] < 1700) | (data_pa['YR_REMODEL'] > 2025))]

# %%
data_pa['BUILDING_AGE'] = 2025 - data_pa['YR_BUILT']

# %%
data_pa['YEARS_SINCE_REMODEL'] = 2025 - data_pa['YR_REMODEL']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Columns to visualize
age_cols = ['BUILDING_AGE', 'YEARS_SINCE_REMODEL']

# Plot settings
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
axes = axes.flatten()

for i, col in enumerate(age_cols):
    sns.histplot(data_pa[col].dropna(), bins=50, kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col.replace('_', ' ').title()}")
    axes[i].set_xlabel(col.replace('_', ' ').title())
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
data_pa
# Out:
#                PID  CM_ID      GIS_ID  ST_NUM          ST_NAME UNIT_NUM  \
# 0        100001000    NaN   100001000   104.0        PUTNAM ST      NaN
# 1        100002000    NaN   100002000   197.0     Lexington ST      NaN
# 2        100003000    NaN   100003000   199.0     Lexington ST      NaN
# 3        100004000    NaN   100004000   201.0     Lexington ST      NaN
# 4        100005000    NaN   100005000   203.0     Lexington ST      NaN
# ...            ...    ...         ...     ...              ...      ...
# 183440  2205666000    NaN  2205666000     NaN       KNOWLES ST      NaN
# 183441  2205667000    NaN  2205667000     NaN          Lake ST      NaN
# 183442  2205668000    NaN  2205668000     4.0          Lake ST      NaN
# 183443  2205669000    NaN  2205669000  2193.0  COMMONWEALTH AV      NaN
# 183444  2205670000    NaN  2205670000  2203.0  COMMONWEALTH AV      NaN
#
#                CITY  ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC       LU  \
# ...

# %%
missing_summary = data_pa.isnull().mean().sort_values(ascending=False)
print(missing_summary[missing_summary > 0.2])  # Shows columns with missing %
# Out:
# UNIT_NUM       0.542891
# YR_REMODEL     0.520399
# CM_ID          0.483646
# TT_RMS         0.265455
# BED_RMS        0.265040
# NUM_PARKING    0.264141
# dtype: float64

# %%
data_pa['YEARS_SINCE_REMODEL'] = data_pa['YEARS_SINCE_REMODEL'].fillna(data_pa['BUILDING_AGE'])

# %%
data_pa = data_pa.drop_duplicates()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Columns to visualize
cols_to_viz = ['UNIT_NUM', 'YR_REMODEL', 'CM_ID', 'TT_RMS', 'BED_RMS', 'NUM_PARKING']

# Setup plot
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 12))
axes = axes.flatten()

# Plot each column
for i, col in enumerate(cols_to_viz):
    sns.histplot(data_pa[col].dropna(), bins=50, kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
data_pa = data_pa.drop(columns='UNIT_NUM')

# %%
data_pa = data_pa.drop(columns='CM_ID')

# %%
room_cols = ['TT_RMS', 'BED_RMS']
for col in room_cols:
    median_val = data_pa[col].median()
    data_pa[col] = data_pa[col].fillna(median_val)

# %%
# Cap outliers
data_pa['NUM_PARKING'] = data_pa['NUM_PARKING'].clip(upper=data_pa['NUM_PARKING'].quantile(0.99))

# Add flag
data_pa['HAS_PARKING'] = data_pa['NUM_PARKING'].notna().astype(int)

# Impute
data_pa['NUM_PARKING'] = data_pa['NUM_PARKING'].fillna(0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols_to_viz_post_cleaning = ['TT_RMS', 'BED_RMS', 'NUM_PARKING', 'HAS_PARKING']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
axes = axes.flatten()

for i, col in enumerate(cols_to_viz_post_cleaning):
    sns.histplot(data_pa[col].dropna(), bins=50, kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
data_pa.to_csv("cleaned_property_Asses_data.csv", index=False)
